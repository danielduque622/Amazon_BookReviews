# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reviews_dd = pd.read_csv('data/Book_review.csv')

# %%
def dim():
  dimensions = len(set(reviews_dd['text'].str.split().explode().values))
  print(f'{dimensions} dimensions in the potential DFM.')
dim()
# Out:
# 52779 dimensions in the potential DFM.

# %%
# top 20 words 
freq = pd.Series(' '.join(reviews_dd['text']).split()).value_counts()[:20]
freq
# Out:
# the     24650
# and     18950
# to      15593
# a       14378
# of      13953
# is       9030
# I        8732
# in       8406
# that     6459
# for      5206
# this     5106
# with     4562
# was      4321
# book     4203
# her      4078
# it       3785
# as       3408
# are      3108
# but      2754
# on       2719
# Name: count, dtype: int64

# %%
# convert all words into lower cases
reviews_dd['text'] = reviews_dd['text'].str.lower()

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danielduque/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop = stopwords.words('english')
reviews_dd['text'] = reviews_dd['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
# top 20 words after removing stop words and making all words lower case
freq = pd.Series(' '.join(reviews_dd['text']).split()).value_counts()[:20]
freq
dim()
# Out:
# 48355 dimensions in the potential DFM.

# %%
# remove punctuation
reviews_dd['text'] = reviews_dd['text'].str.replace(r'[^\w\s]+', '',regex=True)
dim()
# Out:
# 30576 dimensions in the potential DFM.

# %%
# perform stremming
from nltk.stem import PorterStemmer
st = PorterStemmer()
reviews_dd['text'] = reviews_dd['text'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
dim()
# Out:
# 21924 dimensions in the potential DFM.

# %%
# check top words
freq = pd.Series(' '.join(reviews_dd['text']).split()).value_counts()[:20]
freq
# Out:
# book       6546
# read       2826
# stori      2290
# one        2134
# love       1690
# like       1661
# time       1541
# charact    1322
# life       1218
# make       1178
# get        1119
# author     1115
# would      1056
# well        985
# also        967
# way         963
# it          953
# first       943
# famili      920
# want        891
# Name: count, dtype: int64

# %%
stop += ['make','get','would','well','also','way','it','first','want']
reviews_dd['text'] = reviews_dd['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
# check top words
freq = pd.Series(' '.join(reviews_dd['text']).split()).value_counts()[:20]
freq
# Out:
# book       6546
# read       2826
# stori      2290
# one        2134
# love       1690
# like       1661
# time       1541
# charact    1322
# life       1218
# author     1115
# famili      920
# realli      875
# mani        867
# find        863
# good        859
# enjoy       851
# much        842
# seri        832
# go          825
# work        824
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
comment_words = str(' '.join(reviews_dd['text']).split())

# %%
import string
comment_words = comment_words.translate(str.maketrans('','',string.punctuation))
wordcloud = WordCloud(background_color='white',
max_words=200,
width=1000,height=1000,
).generate(comment_words)
plt.figure(figsize=(8,8))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
doc_complete = reviews_dd.text
doc_complete
# Out:
# 0       bought book sincer attempt understand anyon ad...
# 1       read experi probabl deserv 4 star cruelli dedu...
# 2       seraphina arden wellknown scandal view equal p...
# 3       great book featur two wellwritten teenag main ...
# 4       book lot interest thing genet schizophrenia po...
#                               ...
# 2803    book phenomen brilliantli written watch mauric...
# 2804    charact wonder stori realli drew joy go along ...
# 2805    second book compani love one beauti floral the...
# 2806    met lesli blodgett year ago grew love bare min...
# 2807    attract book long publish alkalin water machin...
# Name: text, Length: 2808, dtype: object

# %%
# tokenize each review
corpus = [doc.split() for doc in doc_complete]
corpus
# Out:
# [['bought',
#   'book',
#   'sincer',
#   'attempt',
#   'understand',
#   'anyon',
#   'advoc',
#   'social',
#   'got',
#   'descript',
#   'problem',
#   'follow',
#   'bunch',
#   'histori',
#   'follow',
#   'playbook',
#   'launch',
#   'socialist',
#   'agenda',
#   'lack',
#   'connect',
#   'social',
#   'fact',
#   'solv',
#   'problem',
#   'note',
#   'start',
#   'bookso',
#   'problem',
#   'author',
#   'see',
#   'live',
#   'system',
#   'exploit',
#   'work',
#   'peopl',
#   'result',
#   'class',
#   'unfairli',
#   'better',
#   'everyon',
#   'els',
#   'grind',
#   'thru',
#   'life',
#   'paycheck',
#   'paycheck',
#   'littl',
#   'protect',
#   'calam',
#   'author',
#   'state',
#   'proof',
#   'live',
#   'social',
#   'thing',
#   'fair',
#   'peopl',
#   'better',
#   'offw',
#   'go',
#   '6',
#   'chapter',
#   'recount',
#   'histor',
#   'movement',
#   'time',
#   'period',
#   'variou',
#   'form',
#   'social',
#   'partial',
#   'fulli',
#   'implement',
#   'author',
#   'give',
#   'decent',
#   'retel',
#   'point',
#   'good',
#   'bad',
#   'yet',
#   'chapter',
#   'found',
#   'mani',
#   'nuanc',
#   'bia',
#   'undermin',
#   'attempt',
#   'convinc',
#   'look',
#   'social',
#   'potenti',
#   'answer',
#   'mani',
#   'refer',
#   'capitalist',
#   'system',
#   'fact',
#   'produc',
#   'greater',
#   'output',
#   'could',
#   'otherwis',
#   'achiev',
#   'time',
#   'undermin',
#   'need',
#   'look',
#   'social',
#   'answerher',
#   'exampl',
#   'bia',
#   'note',
#   'britain',
#   'outproduc',
#   'nation',
#   'product',
#   'coal',
#   'could',
#   'therefor',
#   'build',
#   'need',
#   'worker',
#   'manufactur',
#   'facil',
#   'page',
#   '38',
#   'note',
#   'fortun',
#   'capitalist',
#   'agricultur',
#   'boom',
#   'left',
#   'mani',
#   'poverti',
#   'forc',
#   'move',
#   'citi',
#   'work',
#   'factori',
#   'fortun',
#   'perhap',
#   'fortun',
#   'popul',
#   'job',
#   'differ',
#   'fieldh',
#   'refer',
#   'bolshevik',
#   'revolut',
#   'nobl',
#   'page',
#   '81',
#   'white',
#   'movement',
#   'russia',
#   'unholi',
#   'page97',
#   'head',
#   'bolshevik',
#   'secret',
#   'polic',
#   'felix',
#   'dzershinski',
#   'call',
#   'harden',
#   'man',
#   'quick',
#   'interrog',
#   'peopl',
#   'shot',
#   'yet',
#   'white',
#   'movement',
#   'call',
#   'terror',
#   'murder',
#   'peopl',
#   'page',
#   '97',
#   'gem',
#   'page',
#   '98',
#   'dure',
#   'civil',
#   'war',
#   'bolshevik',
#   'blur',
#   'line',
#   'action',
#   'taken',
#   'necess',
#   'perform',
#   'virtuenot',
#   'previou',
#   'review',
#   'author',
#   'ultim',
#   'exampl',
#   'bia',
#   'yet',
#   'look',
#   'away',
#   'human',
#   'toll',
#   'moment',
#   'see',
#   'five',
#   'year',
#   'plan',
#   'successth',
#   'soviet',
#   'union',
#   'made',
#   'incred',
#   'advancesst',
#   'plan',
#   'led',
#   'rapid',
#   'rise',
#   'gdp',
#   'line',
#   'later',
#   'author',
#   'note',
#   'new',
#   'deadli',
#   'polit',
#   'terror',
#   'campaign',
#   'mass',
#   'murder',
#   'began',
#   'stalintransform',
#   'soviet',
#   'unioninto',
#   'horrif',
#   'totalitarian',
#   'regim',
#   'page',
#   '102',
#   'gee',
#   'trade',
#   'close',
#   'eye',
#   'notic',
#   'million',
#   'kill',
#   'celebr',
#   'growth',
#   'gdp',
#   'like',
#   'say',
#   'could',
#   'ignor',
#   'nazi',
#   'atroc',
#   'see',
#   'past',
#   'bad',
#   'stuff',
#   'give',
#   'kudo',
#   'nice',
#   'highway',
#   'full',
#   'employmenti',
#   'could',
#   'fill',
#   'exampl',
#   'drift',
#   'socialist',
#   'someth',
#   'bad',
#   'benefit',
#   'doubt',
#   'capitalist',
#   'evilther',
#   'numer',
#   'exampl',
#   'admiss',
#   'capit',
#   'actual',
#   'produc',
#   'higher',
#   'abund',
#   'output',
#   'almost',
#   'everi',
#   'chapter',
#   'histori',
#   'section',
#   'note',
#   'exampl',
#   'growth',
#   'higher',
#   'output',
#   'produc',
#   'capitalist',
#   'system',
#   'fact',
#   'page',
#   '131',
#   'author',
#   'note',
#   'marx',
#   'understood',
#   'socialist',
#   'revolut',
#   'come',
#   'capit',
#   'produc',
#   'enough',
#   'abund',
#   'creat',
#   'class',
#   'system',
#   'bottom',
#   'could',
#   'stir',
#   'bring',
#   'social',
#   'lifei',
#   'learn',
#   'new',
#   'insight',
#   'fail',
#   'attempt',
#   'call',
#   'socialist',
#   'third',
#   'world',
#   'bring',
#   'real',
#   'chang',
#   'page',
#   '153156',
#   'afghanistanfail',
#   'angolafail',
#   'mozambiquefail',
#   'vietnamfail',
#   'zimbabwefail',
#   'tanzaniafail',
#   'cubafail',
#   'appar',
#   'countri',
#   'develop',
#   'economi',
#   'social',
#   'workthen',
#   'rather',
#   'dubiou',
#   'stretch',
#   'logic',
#   'connect',
#   'dot',
#   'page',
#   '198',
#   'somehow',
#   'connect',
#   'shoot',
#   'michael',
#   'brown',
#   'st',
#   'loui',
#   '2014',
#   'failur',
#   'american',
#   'democraci',
#   'could',
#   'possibl',
#   'poor',
#   'polic',
#   'practic',
#   'victim',
#   'attempt',
#   'take',
#   'offic',
#   'weapon',
#   'earth',
#   'failur',
#   'democraci',
#   'page',
#   '240',
#   'cue',
#   'comment',
#   'capit',
#   'creat',
#   'climat',
#   'crisi',
#   'could',
#   'destroy',
#   'civil',
#   'know',
#   'state',
#   'absolut',
#   'fact',
#   'support',
#   'mention',
#   'massiv',
#   'amount',
#   'pollut',
#   'creat',
#   'coal',
#   'burn',
#   'communist',
#   'chinaso',
#   'final',
#   'last',
#   'coupl',
#   'chapter',
#   'socialist',
#   'take',
#   'ie',
#   'gameplan1',
#   'socialist',
#   'must',
#   'creat',
#   'class',
#   'divis',
#   'constantli',
#   'bring',
#   'attent',
#   'unjust',
#   'outcom',
#   'capit',
#   'fuel',
#   'peopl',
#   'anger',
#   'system2',
#   'street',
#   'protest',
#   'strike',
#   'use',
#   'disciplin',
#   'wayward',
#   'polit',
#   'candid',
#   'go',
#   'along',
#   'redistribut',
#   'agenda3',
#   'socialist',
#   'reliant',
#   'continu',
#   'profit',
#   'privat',
#   'compani',
#   'pay',
#   'agenda',
#   'tri',
#   'win',
#   'reform',
#   'medicar',
#   'free',
#   'child',
#   'care',
#   'etc',
#   'use',
#   'profit',
#   'privat',
#   'companies4',
#   'socialist',
#   'must',
#   'gain',
#   'decis',
#   'major',
#   'legislatur',
#   'flex',
#   'social',
#   'muscl',
#   'via',
#   'mass',
#   'protest',
#   'strike',
#   'choos',
#   'confront',
#   'accommodation5',
#   'elit',
#   'ideolog',
#   'socialist',
#   'best',
#   'perceiv',
#   'class',
#   'relat',
#   'must',
#   'compromis',
#   'instead',
#   'opt',
#   'disrupt',
#   'role',
#   'politics6',
#   'elit',
#   'colleg',
#   'educ',
#   'import',
#   'train',
#   'larg',
#   'group',
#   'effect',
#   'speaker',
#   'writer',
#   'sharp',
#   'thinkers7',
#   'socialist',
#   'focu',
#   'take',
#   'job',
#   'emerg',
#   'sector',
#   'economi',
#   'educ',
#   'healthcar',
#   'suppli',
#   'logist',
#   'creat',
#   'union',
#   'creat',
#   'support',
#   'strikes8',
#   'socialist',
#   'need',
#   'creat',
#   'new',
#   'mass',
#   'membership',
#   'parti',
#   'organ',
#   'deleg',
#   'put',
#   'candid',
#   'elect',
#   'levels9',
#   'abolish',
#   'elector',
#   'colleg',
#   'chang',
#   'constitut',
#   'unicamer',
#   'legislatur',
#   'proport',
#   'representationso',
#   'real',
#   'answer',
#   'social',
#   'creat',
#   'better',
#   'societi',
#   'discuss',
#   'work',
#   'real',
#   'life',
#   'empir',
#   'evid',
#   'solv',
#   'problem',
#   'discuss',
#   'chang',
#   'tax',
#   'code',
#   'break',
#   'big',
#   'bank',
#   'addit',
#   'regul',
#   'solutionth',
#   'author',
#   'simpli',
#   'keep',
#   'repeat',
#   'socialist',
#   'peopl',
#   'say',
#   'system',
#   'fair',
#   'socialist',
#   'thing',
#   'like',
#   'free',
#   'child',
#   'care',
#   'free',
#   'colleg',
#   'free',
#   'healthcar',
#   'socialist',
#   'discrimin',
#   'equal',
#   'right',
#   'women',
#   'minor',
#   'coher',
#   'case',
#   'social',
#   'answer',
#   'problemsi',
#   'realli',
#   'read',
#   'book',
#   'open',
#   'mind',
#   'someth',
#   'bite',
#   'understand',
#   'found',
#   'book',
#   'lack'],
#  ['read',
#   'experi',
#   'probabl',
#   'deserv',
#   '4',
#   'star',
#   'cruelli',
#   'deduct',
#   'one',
#   'book',
#   'could',
#   'use',
#   'littl',
#   'flesh',
#   'bone',
#   'fine',
#   'read',
#   'quit',
#   'know',
#   'brook',
#   'selfconsci',
#   'describ',
#   'pamphlet',
#   'probabl',
#   'work',
#   'gener',
#   'analysi',
#   'cohes',
#   'articul',
#   'strategi',
#   'philosophi',
#   'mostli',
#   'consist',
#   'specif',
#   'singledout',
#   'critiqu',
#   'brook',
#   'see',
#   'biggest',
#   'weak',
#   'harri',
#   'peterson',
#   'shapiro',
#   'mostli',
#   'boil',
#   'harri',
#   'socal',
#   'thought',
#   'experi',
#   'disingenu',
#   'attempt',
#   'camouflag',
#   'bias',
#   'peterson',
#   'defens',
#   'hierarchi',
#   'selfserv',
#   'generaliz',
#   'polit',
#   'water',
#   'like',
#   'swim',
#   'far',
#   'beyond',
#   'expertis',
#   'ben',
#   'shapiro',
#   'shitpost',
#   'true',
#   'enough',
#   'flaw',
#   'individu',
#   'whove',
#   'attract',
#   'larg',
#   'fartoo',
#   'ingenu',
#   'followingth',
#   'problem',
#   'brook',
#   'overal',
#   'thesi',
#   'left',
#   'need',
#   'look',
#   'hard',
#   'void',
#   'idw',
#   'fill',
#   'peopl',
#   'caus',
#   'flash',
#   'pan',
#   'speak',
#   'need',
#   'honesti',
#   'sophist',
#   'order',
#   'avoid',
#   'margin',
#   'peopl',
#   'could',
#   'probabl',
#   'convinc',
#   'error',
#   'complet',
#   'agre',
#   'think',
#   'book',
#   'realli',
#   'audienc',
#   'outsid',
#   'peopl',
#   'alreadi',
#   'watch',
#   'show',
#   'seem',
#   'leftlean',
#   'peopl',
#   'outsid',
#   'extrem',
#   'onlin',
#   'varieti',
#   'spend',
#   'lot',
#   'time',
#   'listen',
#   'podcast',
#   'mostli',
#   'disinterest',
#   'narrowli',
#   'delin',
#   'critic',
#   'three',
#   'individu',
#   'unclear',
#   'connect',
#   'central',
#   'point',
#   'book',
#   'rightlean',
#   'centrist',
#   'cough',
#   'hyperonlin',
#   'peopl',
#   'irrit',
#   'folk',
#   'spent',
#   'hundr',
#   'hour',
#   'digest',
#   'reduc',
#   'weakest',
#   'embarrass',
#   'moment',
#   'goodfaith',
#   'actor',
#   'among',
#   'might',
#   'admit',
#   'area',
#   'peopl',
#   'admir',
#   'goof',
#   'put',
#   'impress',
#   'target',
#   'critiqu',
#   'effort',
#   'smuggl',
#   'polit',
#   'stanc',
#   'predispos',
#   'rejectin',
#   'brook',
#   'defens',
#   'seem',
#   'awar',
#   'thi',
#   'wise',
#   'avoid',
#   'spend',
#   'much',
#   'time',
#   'dunk',
#   'note',
#   'dope',
#   'dave',
#   'rubin',
#   'hi',
#   'restraint',
#   'palpabl',
#   'hilari',
#   'still',
#   'flavor',
#   'book',
#   'obvious',
#   'come',
#   'someon',
#   'whose',
#   'publicfac',
#   'work',
#   'mostli',
#   'consist',
#   'quick',
#   'polit',
#   'reaction',
#   'hot',
#   'take',
#   'instinct',
#   'come',
#   'pretti',
#   'clearli',
#   'real',
#   'thing',
#   'say',
#   'weinstein',
#   'brother',
#   'write',
#   'bland',
#   'move',
#   'give',
#   'anoth',
#   'nod',
#   'briefli',
#   'mention',
#   'rucku',
#   'evergreen',
#   'colleg',
#   'embarrass',
#   'moment',
#   'leftist',
#   'overreact',
#   'unfortun',
#   'made',
#   'weinstein',
#   'famou',
#   'one',
#   'suspect',
#   'seriou',
#   'critiqu',
#   'appeal',
#   'brook',
#   'hunger',
#   'red',
#   'meat',
#   'think',
#   'wast',
#   'opportunityto',
#   'lay',
#   'card',
#   'tabl',
#   'leftlean',
#   'probabl',
#   'someon',
#   'michael',
#   'brook',
#   'consid',
#   'neoliber',
#   'enlightenedcentrist',
#   'respect',
#   'fine',
#   'actual',
#   'lot',
#   'jordan',
#   'peterson',
#   'even',
#   'agre',
#   'polit',
#   'embarrassingli',
#   'halfinform',
#   'serious',
#   'take',
#   'glad',
#   'exist',
#   'admit',
#   'suspect',
#   'use',
#   'pull',
#   'peopl',
#   'back',
#   'modern',
#   'nascent',
#   'nazism',
#   'comment',
#   'left',
#   'think',
#   'flaw',
#   'honest',
#   'basic',
#   'consequentialist',
#   'glad',
#   'admit',
#   'left',
#   'correct',
#   'side',
#   'argument',
#   'fear',
#   'unintent',
#   'fallout',
#   'overreach',
#   'upheav',
#   'disagre',
#   'least',
#   'defens',
#   'harri',
#   'much',
#   'ass',
#   'fact',
#   'leftlean',
#   'atheist',
#   'talk',
#   'gateway',
#   'altright',
#   'outright',
#   'indict',
#   'much',
#   'leftist',
#   'habit',
#   'present',
#   'total',
#   'fauxsteril',
#   'tonguecluckingli',
#   'moralist',
#   'worldview',
#   'utter',
#   'poison',
#   'term',
#   'convinc',
#   'peopl',
#   'someth',
#   'wrong',
#   'need',
#   'chang',
#   'brook',
#   'focu',
#   'vampir',
#   'castl',
#   'show',
#   'think',
#   'agre',
#   'left',
#   'cant',
#   'chase',
#   'peopl',
#   'away',
#   'drip',
#   'disdain',
#   'harri',
#   'obviou',
#   'frankli',
#   'think',
#   'harri',
#   'peopl',
#   'like',
#   'save',
#   'peterson',
#   'mani',
#   'peopl',
#   'like',
#   'opinion',
#   'unconsci',
#   'lot',
#   'foibl',
#   'prone',
#   'defens',
#   'rest',
#   'like',
#   'anyon',
#   'consid',
#   'goodfaith',
#   'actor',
#   'reachabl',
#   'long',
#   'feel',
#   'like',
#   'egoselfhood',
#   'thing',
#   'pull',
#   'onto',
#   'butcher',
#   'block',
#   'keep',
#   'mind',
#   'harri',
#   'someon',
#   'like',
#   'sander',
#   'view',
#   'trump',
#   'horror',
#   'weinstein',
#   'brother',
#   'sander',
#   'support',
#   'peterson',
#   'classic',
#   'liber',
#   'heard',
#   'say',
#   'anyth',
#   'critic',
#   'canadian',
#   'healthcar',
#   'social',
#   'safeti',
#   'net',
#   'oper',
#   'bubbl',
#   'peopl',
#   'practic',
#   'reachabl',
#   'dialogu',
#   'slowli',
#   'pain',
#   'price',
#   'ironi',
#   'web',
#   'treat',
#   'like',
#   'enemi',
#   'warn',
#   'chill',
#   'effect',
#   'thingal',
#   'said',
#   'like',
#   'michael',
#   'brook',
#   'hear',
#   'think',
#   'right',
#   'treat',
#   'shapiro',
#   'like',
#   'hack',
#   'badfaith',
#   'actor',
#   'less',
#   'said',
#   'rubin',
#   'better',
#   'brook',
#   'indict',
#   'idw',
#   'dishonest',
#   'treat',
#   'rubin',
#   'friendli',
#   'respect',
#   'ring',
#   'true',
#   'speak',
#   'human',
#   'fear',
#   'circl',
#   'wagon',
#   'fire',
#   'inward',
#   'true',
#   'regardless',
#   'hope',
#   'author',
#   'continu',
#   'move',
#   'across',
#   'bridg',
#   'joke',
#   'onlin',
#   'provocateur',
#   'clearli',
#   'bright',
#   'funni',
#   'guy',
#   'think',
#   'right',
#   'intent',
#   'like',
#   'best',
#   'peopl',
#   'oppos',
#   'flaw',
#   'like',
#   'anyon',
#   'itch',
#   'prick',
#   'understand',
#   'probabl',
#   'forc',
#   'good',
#   'end',
#   'like',
#   'web',
#   'clear',
#   'throat',
#   'someth',
#   'fullbodi',
#   'futur'],
#  ['seraphina',
#   'arden',
#   'wellknown',
#   'scandal',
#   'view',
#   'equal',
#   'penchant',
#   'take',
#   'lover',
#   'propens',
#   'winedrink',
#   'hope',
#   'open',
#   'institut',
#   'train',
#   'women',
#   'work',
#   'trade',
#   'usual',
#   'reserv',
#   'men',
#   'rais',
#   'fund',
#   'decid',
#   'publish',
#   'memoir',
#   'expos',
#   'sordid',
#   'past',
#   'power',
#   'man',
#   'set',
#   'road',
#   'ruin',
#   'singular',
#   'purpos',
#   'hold',
#   'friend',
#   'famili',
#   'ensur',
#   'lover',
#   'gone',
#   'morningadam',
#   'anderson',
#   'widow',
#   'scottish',
#   'architect',
#   'spend',
#   'summer',
#   'work',
#   'project',
#   'cornwal',
#   'two',
#   'children',
#   'burgeon',
#   'busi',
#   'protect',
#   'cant',
#   'afford',
#   'affair',
#   'certainli',
#   'scandal',
#   'seraphina',
#   'arden',
#   'spend',
#   'summer',
#   'nativ',
#   'cornwal',
#   'propos',
#   'string',
#   'attach',
#   'month',
#   'prove',
#   'tempt',
#   'adam',
#   'buri',
#   'passion',
#   'natur',
#   'grief',
#   'past',
#   'three',
#   'yearsa',
#   'simpl',
#   'fling',
#   'rapidli',
#   'grow',
#   'far',
#   'complic',
#   'emot',
#   'ignit',
#   'feel',
#   'neither',
#   'expect',
#   'experi',
#   'sera',
#   'learn',
#   'adam',
#   'career',
#   'stake',
#   'good',
#   'favor',
#   'man',
#   'cusp',
#   'call',
#   'memoir',
#   'must',
#   'decid',
#   'caus',
#   'hearti',
#   'mani',
#   'feel',
#   'thought',
#   'book',
#   'may',
#   'bit',
#   'rambl',
#   'look',
#   'forward',
#   'must',
#   'say',
#   'expect',
#   'bit',
#   'disappoint',
#   'doubt',
#   'book',
#   'impecc',
#   'wellwritten',
#   'bit',
#   'wordi',
#   'place',
#   'opinion',
#   'least',
#   'isnt',
#   'realli',
#   'romanc',
#   'feminist',
#   'treatis',
#   'expect',
#   'read',
#   'literatur',
#   'class',
#   'discuss',
#   'seriousmind',
#   'book',
#   'club',
#   'certainli',
#   'job',
#   'respect',
#   'put',
#   'frame',
#   'mind',
#   'true',
#   'feminist',
#   'live',
#   'terrifi',
#   'time',
#   'women',
#   'virtual',
#   'right',
#   'illumin',
#   'contrast',
#   'true',
#   'mean',
#   'purpos',
#   'femin',
#   'today',
#   'water',
#   'easili',
#   'offend',
#   'version',
#   'romancesera',
#   'relationship',
#   'adam',
#   'took',
#   'backseat',
#   'liter',
#   'everyth',
#   'els',
#   'book',
#   'adam',
#   'never',
#   'given',
#   'much',
#   'opportun',
#   'growth',
#   'depth',
#   'one',
#   'sweetest',
#   'thought',
#   'hero',
#   'ive',
#   'read',
#   'wound',
#   'think',
#   'deserv',
#   'better',
#   'wound',
#   'sera',
#   'backbon',
#   'stop',
#   'come',
#   'back',
#   'time',
#   'sera',
#   'continu',
#   'treat',
#   'horribl',
#   'definit',
#   'sera',
#   'stori',
#   'adam',
#   'thrown',
#   'spice',
#   'wasnt',
#   'much',
#   'substanc',
#   'stori',
#   'coupl',
#   'much',
#   'ever',
#   'realli',
#   'develop',
#   'though',
#   'dont',
#   'think',
#   'relationship',
#   'realli',
#   'much',
#   'point',
#   'honestli',
#   'strong',
#   'principl',
#   'argument',
#   'agre',
#   'sera',
#   'struck',
#   'least',
#   'time',
#   'immatur',
#   'emot',
#   'stunt',
#   'drown',
#   'feel',
#   'alcohol',
#   'throw',
#   'childish',
#   'tantrum',
#   'exhibit',
#   'wa',
#   'core',
#   'selfish',
#   'natur',
#   'much',
#   'time',
#   'felt',
#   'use',
#   'adam',
#   'base',
#   'whim',
#   'unstabl',
#   'emot',
#   'care',
#   'might',
#   'affect',
#   'one',
#   'point',
#   'even',
#   'tri',
#   'forc',
#   'adam',
#   'rather',
#   'unforgiv',
#   'certainli',
#   'role',
#   'revers',
#   'made',
#   'respect',
#   'ebb',
#   'even',
#   'act',
#   'ruin',
#   'women',
#   'one',
#   'ever',
#   'suffer',
#   'life',
#   'grossli',
#   'irrit',
#   'time',
#   'start',
#   'consid',
#   'feel',
#   'even',
#   'bit',
#   'littl',
#   'late',
#   'especi',
#   'given',
#   'fact',
#   'still',
#   'tri',
#   'keep',
#   'thing',
#   'himther',
#   'ridicul',
#   'amount',
#   'back',
#   'forth',
#   'two',
#   'got',
#   'slightli',
#   'past',
#   'book',
#   'especi',
#   'slow',
#   'pace',
#   'pace',
#   'realli',
#   'increas',
#   'larg',
#   'infus',
#   'angst',
#   'alway',
#   'annoy',
#   'though',
#   'say',
#   'done',
#   'felt',
#   'real',
#   'raw',
#   'probabl',
#   'hard',
#   'read',
#   'mistak',
#   'wasnt',
#   'exactli',
#   'romanc',
#   'dont',
#   'think',
#   'wasnt',
#   'steami',
#   'wa',
#   'much',
#   'prefer',
#   'remain',
#   'sensual',
#   'side',
#   'said',
#   'wound',
#   'feel',
#   'like',
#   'steami',
#   'scene',
#   'didnt',
#   'relationship',
#   'adam',
#   'sera',
#   'sera',
#   'ultim',
#   'keep',
#   'adam',
#   'arm',
#   'length',
#   'extent',
#   'distant',
#   'even',
#   'epilogu',
#   'made',
#   'end',
#   'rather',
#   'unsatisfi',
#   'mei',
#   'love',
#   'idea',
#   'role',
#   'revers',
#   'femal',
#   'rake',
#   'enjoy',
#   'part',
#   'read',
#   'rake',
#   'reform',
#   'one',
#   'special',
#   'woman',
#   'dont',
#   'think',
#   'sera',
#   'ever',
#   'even',
#   'came',
#   'close',
#   'even',
#   'end',
#   'still',
#   'marri',
#   'caus',
#   'respect',
#   'ultim',
#   'made',
#   'seem',
#   'bit',
#   'selffocus',
#   'especi',
#   'given',
#   'lack',
#   'consider',
#   'potenti',
#   'respect',
#   'child',
#   'sera',
#   'certainli',
#   'exhibit',
#   'redeem',
#   'qualiti',
#   'never',
#   'realli',
#   'becam',
#   'likabl',
#   'still',
#   'alway',
#   'expect',
#   'much',
#   'ever',
#   'give',
#   'herselfth',
#   'main',
#   'problem',
#   'may',
#   'bit',
#   'grave',
#   'seriou',
#   'tone',
#   'right',
#   'overal',
#   'wellwritten',
#   'book',
#   'given',
#   'end',
#   'somewhat',
#   'cliffhang',
#   'one',
#   'support',
#   'charact',
#   'ill',
#   'probabl',
#   'continu',
#   'seri',
#   'even',
#   'though',
#   'one',
#   'wasnt',
#   'quit',
#   'mei',
#   'voluntarili',
#   'read',
#   'review',
#   'advanc',
#   'copi',
#   'book',
#   'thought',
#   'opinion'],
#  ['great',
#   'book',
#   'featur',
#   'two',
#   'wellwritten',
#   'teenag',
#   'main',
#   'charact',
#   'good',
#   'aspect',
#   'bad',
#   'heap',
#   'prais',
#   'tell',
#   'bit',
#   'likei',
#   'realli',
#   'enjoy',
#   'teenag',
#   'girl',
#   'portray',
#   'neither',
#   'childish',
#   'grown',
#   'charact',
#   'facet',
#   'adulthood',
#   'childhood',
#   'plenti',
#   'friction',
#   'obnoxi',
#   'overblown',
#   'teenag',
#   'angst',
#   'much',
#   'teen',
#   'fiction',
#   'use',
#   'fuel',
#   'petti',
#   'melodrama',
#   'conflict',
#   'actual',
#   'emot',
#   'weight',
#   'found',
#   'believ',
#   'likabl',
#   'pretti',
#   'unusu',
#   'teenag',
#   'charact',
#   'teenag',
#   'often',
#   'badli',
#   'written',
#   'portray',
#   'childish',
#   'stupid',
#   'often',
#   'found',
#   'hard',
#   'take',
#   'serious',
#   'endur',
#   'case',
#   'herefor',
#   'matter',
#   'everyon',
#   'book',
#   'balanc',
#   'sort',
#   'charact',
#   'nobodi',
#   'outsid',
#   'villain',
#   'perfect',
#   'flaw',
#   'interperson',
#   'relationship',
#   'feel',
#   'familiar',
#   'hit',
#   'close',
#   'home',
#   'even',
#   'ownth',
#   'plot',
#   'enjoy',
#   'pageturn',
#   'forgiv',
#   'clich',
#   'read',
#   'two',
#   'day',
#   'usual',
#   'someon',
#   'bounc',
#   'around',
#   'book',
#   'one',
#   'held',
#   'attent',
#   'continu',
#   'guess',
#   'ask',
#   'question',
#   'end',
#   'much',
#   'like',
#   'one',
#   'main',
#   'charact',
#   'root',
#   'certain',
#   'outcom',
#   'avoid',
#   'spoiler',
#   'say',
#   'happi',
#   'outcom',
#   'happenand',
#   'final',
#   'express',
#   'admir',
#   'makeout',
#   'scene',
#   'say',
#   'found',
#   'titil',
#   'take',
#   'skill',
#   'writer',
#   'address',
#   'teenag',
#   'libido',
#   'neither',
#   'author',
#   'handwav',
#   'scene',
#   'away',
#   'hit',
#   'territori',
#   'erotica',
#   'felt',
#   'realist',
#   'detail',
#   'gross',
#   'scene',
#   'start',
#   'flinch',
#   'littl',
#   'afraid',
#   'might',
#   'cringey',
#   'never',
#   'beauti',
#   'handl',
#   'bravoso',
#   'bad',
#   'keep',
#   'mind',
#   'somewhat',
#   'minor',
#   'thing',
#   'even',
#   'though',
#   'detail',
#   'like',
#   'themfirst',
#   'book',
#   'set',
#   'wwii',
#   'era',
#   'know',
#   'peopl',
#   'like',
#   'feel',
#   'like',
#   'done',
#   'death',
#   'zombi',
#   'vampir',
#   'combin',
#   'got',
#   'nab',
#   'random',
#   'book',
#   'scifi',
#   'fantasi',
#   'section',
#   'decid',
#   'read',
#   'whatev',
#   'got',
#   'bit',
#   'rut',
#   'read',
#   'late',
#   'normal',
#   'alon',
#   'wouldv',
#   'caus',
#   'give',
#   'book',
#   'pass',
#   'mani',
#   'war',
#   'histori',
#   'mani',
#   'type',
#   'peopl',
#   'cultur',
#   'thing',
#   'happen',
#   'one',
#   'sliver',
#   'histori',
#   'much',
#   'fiction',
#   'put',
#   'pretti',
#   'much',
#   'everyon',
#   'surviv',
#   'wwii',
#   'dead',
#   'none',
#   'us',
#   'realli',
#   'need',
#   'catharsi',
#   'realli',
#   'keep',
#   'beat',
#   'dead',
#   'hors',
#   'peopl',
#   'pick',
#   'anoth',
#   'war',
#   'anoth',
#   'place',
#   'anoth',
#   'time',
#   'issu',
#   'like',
#   'nazi',
#   'racism',
#   'nazi',
#   'villain',
#   'feel',
#   'pretti',
#   'lazi',
#   'develop',
#   'nobodi',
#   'question',
#   'good',
#   'bad',
#   'stock',
#   'flat',
#   'low',
#   'effort',
#   'bad',
#   'guy',
#   'befal',
#   'fate',
#   'without',
#   'mar',
#   'main',
#   'charact',
#   'moralityanoth',
#   'thing',
#   'worth',
#   'note',
#   'begin',
#   'end',
#   'littl',
#   'bit',
#   'eh',
#   'author',
#   'husband',
#   'put',
#   'frontload',
#   'exposit',
#   'four',
#   'charact',
#   'gender',
#   'basic',
#   'introduc',
#   'time',
#   'exposit',
#   'thought',
#   'exposit',
#   'dialogu',
#   'one',
#   'anoth',
#   'simultan',
#   'includ',
#   'good',
#   'deal',
#   'inform',
#   'magic',
#   'work',
#   'almost',
#   'made',
#   'toss',
#   'book',
#   'glad',
#   'slog',
#   'bit',
#   'major',
#   'goodth',
#   'epilogu',
#   'hand',
#   'feel',
#   'realli',
#   'cheap',
#   'actual',
#   'roll',
#   'eye',
#   'last',
#   'chapter',
#   'perfect',
#   'beauti',
#   'end',
#   'kind',
#   'end',
#   'good',
#   'novel',
#   'epilogu',
#   'goe',
#   'scene',
#   'none',
#   'infer',
#   'go',
#   'happen',
#   'pull',
#   'cheap',
#   'sortof',
#   'cliffhang',
#   'littl',
#   'insult',
#   'complet',
#   'unnecessari',
#   'given',
#   'one',
#   'book',
#   'major',
#   'flaw',
#   'attempt',
#   'rope',
#   'next',
#   'one',
#   'ever',
#   'realli',
#   'good',
#   'date',
#   'even',
#   'home',
#   'person',
#   'know',
#   'next',
#   'date',
#   'know',
#   'instanc',
#   'think',
#   'probabl',
#   'wouldv',
#   'next',
#   'date',
#   'made',
#   'weird',
#   'epilogu',
#   'made',
#   'weird',
#   'away',
#   'pull',
#   'tv',
#   'show',
#   'next',
#   'episod',
#   'best',
#   'month',
#   'away',
#   'book',
#   'probabl',
#   'gonna',
#   'least',
#   'year',
#   'next',
#   'one',
#   'cool',
#   'tactic',
#   'go',
#   'peopl',
#   'line',
#   'long',
#   'read',
#   'prior',
#   'purchas',
#   'skip',
#   'epilogu',
#   'serious',
#   'rip',
#   'epilogu',
#   'book',
#   'start',
#   'set',
#   'fire',
#   'tempt',
#   'weird',
#   'date',
#   'booki',
#   'go',
#   'note',
#   'say',
#   'good',
#   'book',
#   'probabl',
#   'read',
#   'seri',
#   'uh',
#   'gonna',
#   'wait',
#   'week',
#   'two',
#   'call',
#   'back'],
#  ['book',
#   'lot',
#   'interest',
#   'thing',
#   'genet',
#   'schizophrenia',
#   'possibl',
#   'prevent',
#   'schizophrenia',
#   'supplement',
#   'fetu',
#   'still',
#   'form',
#   'grow',
#   'appreci',
#   'fact',
#   'author',
#   'acknowledg',
#   'much',
#   'chang',
#   'treatment',
#   'mental',
#   'ill',
#   'sinc',
#   'boy',
#   'grow',
#   '1950',
#   '1960',
#   'correct',
#   'much',
#   'chang',
#   'coupl',
#   'problem',
#   'book',
#   '1',
#   'author',
#   'say',
#   'heart',
#   'condit',
#   'caus',
#   'drug',
#   'given',
#   'schizophren',
#   'year',
#   'rare',
#   'next',
#   'paragraph',
#   'say',
#   'ten',
#   'thousand',
#   'peopl',
#   'die',
#   'heart',
#   'relat',
#   'issu',
#   'tell',
#   'ten',
#   'thousand',
#   'report',
#   'like',
#   'far',
#   'higher',
#   'peopl',
#   'consid',
#   'mental',
#   'ill',
#   'regard',
#   'highli',
#   'enough',
#   'anyon',
#   'even',
#   'record',
#   'death',
#   'certif',
#   'heart',
#   'attack',
#   'heart',
#   'failur',
#   'caus',
#   'take',
#   'horribl',
#   'medic',
#   'year',
#   'year',
#   'rare',
#   'least',
#   'medic',
#   'author',
#   'acknowledg',
#   'danger',
#   'sad',
#   '2',
#   'find',
#   'unforgiv',
#   'highli',
#   'disturb',
#   'author',
#   'take',
#   'propaganda',
#   'push',
#   'electro',
#   'shock',
#   'treatment',
#   'day',
#   'call',
#   'kinder',
#   'gentler',
#   'electro',
#   'shock',
#   'treatment',
#   'fda',
#   'outlaw',
#   'old',
#   'electro',
#   'shock',
#   'machin',
#   'compani',
#   'scrambl',
#   'new',
#   'version',
#   'one',
#   'current',
#   'use',
#   'push',
#   'fda',
#   'safer',
#   'fact',
#   'kill',
#   'damag',
#   'brain',
#   'cell',
#   'old',
#   'version',
#   'author',
#   'say',
#   'patient',
#   'anesthesia',
#   'oh',
#   'kind',
#   'given',
#   'muscl',
#   'relax',
#   'calm',
#   'less',
#   'anxieti',
#   'ye',
#   'suppos',
#   'come',
#   'handi',
#   'basic',
#   'paralyz',
#   'patient',
#   'institut',
#   'treatment',
#   'done',
#   'fight',
#   'restraint',
#   'give',
#   'muscl',
#   'relax',
#   'bodi',
#   'goe',
#   'violent',
#   'convuls',
#   'bone',
#   'broken',
#   'year',
#   'past',
#   'done',
#   'keep',
#   'peopl',
#   'calm',
#   'anxieti',
#   'free',
#   'billion',
#   'dollar',
#   'industri',
#   'medicar',
#   'bill',
#   'billion',
#   'dollar',
#   'doctor',
#   'take',
#   'patient',
#   'mostli',
#   'femal',
#   'nurs',
#   'home',
#   'give',
#   'electro',
#   'shock',
#   'treatment',
#   'fact',
#   'patient',
#   'given',
#   'tortur',
#   'still',
#   'remain',
#   'medic',
#   'exactli',
#   'accomplish',
#   'author',
#   'throw',
#   'hand',
#   'celebr',
#   'year',
#   'gone',
#   'even',
#   'tri',
#   'far',
#   'cri',
#   'wealthi',
#   'known',
#   'person',
#   'control',
#   'bodi',
#   'decid',
#   'treatment',
#   'two',
#   'see',
#   'help',
#   'vast',
#   'major',
#   'poor',
#   'soul',
#   'forc',
#   'upon',
#   'sometim',
#   'court',
#   'order',
#   'vulner',
#   'peopl',
#   'told',
#   'psychiatrist',
#   'good',
#   'result',
#   'see',
#   'new',
#   'ect',
#   'safe',
#   'done',
#   'throw',
#   'crap',
#   'celebr',
#   'anoth',
#   'part',
#   'tri',
#   'normal',
#   'atroc',
#   'rebrand',
#   'horrif',
#   'abus',
#   'treatment',
#   'electo',
#   'convuls',
#   'therapi',
#   'lie',
#   'peopl',
#   'told',
#   'new',
#   'push',
#   'normal',
#   'disgust',
#   'one',
#   'troubl',
#   'thing',
#   'seen',
#   'lifetim',
#   'money',
#   'profit',
#   'driven',
#   'industri',
#   'abus',
#   'powerless',
#   'peopl',
#   'truth',
#   'someth',
#   'ask',
#   'doctor',
#   'money',
#   'famili',
#   'member',
#   'give',
#   'pass',
#   'allow',
#   'happen',
#   'powerless',
#   'famili',
#   'member',
#   'great',
#   'result',
#   'otherwis',
#   'known',
#   'punch',
#   'drunk',
#   'last',
#   'long',
#   'henc',
#   'reason',
#   'keep',
#   'treatment',
#   'lot',
#   'peopl',
#   'commit',
#   'suicid',
#   'done',
#   'lot',
#   'struggl',
#   'rememb',
#   'children',
#   'name',
#   'read',
#   'famili',
#   'member',
#   'say',
#   'rel',
#   'shell',
#   'zombi',
#   'forev',
#   'rememb',
#   'use',
#   'last',
#   'resort',
#   'everi',
#   'patient',
#   'sold',
#   'depress',
#   'schizophrenia',
#   'author',
#   'point',
#   'schizophrenia',
#   'use',
#   'catch',
#   'label',
#   'thing',
#   'cannot',
#   'lump',
#   'togeth',
#   'one',
#   'categori',
#   'like',
#   'use',
#   'year',
#   'wide',
#   'rang',
#   'symptom',
#   'mani',
#   'option',
#   'take',
#   'easier',
#   'warehous',
#   'peopl',
#   'fri',
#   'brain',
#   'write',
#   'book',
#   'mani',
#   'fact',
#   'present',
#   'mani',
#   'reader',
#   'go',
#   'understand',
#   'socal',
#   'fact',
#   'use',
#   'electro',
#   'shock',
#   'treatment',
#   'noth',
#   'glossi',
#   'pamphlet',
#   'compani',
#   'produc',
#   'machin',
#   'hand',
#   'think',
#   'irrespons',
#   'author',
#   'dig',
#   'deeper',
#   'talk',
#   'famili',
#   'actual',
#   'care',
#   'happen',
#   'someon',
#   'famili',
#   'thi',
#   'read',
#   'someth',
#   'written',
#   'someon',
#   'feel',
#   'destroy',
#   'seen',
#   '3040',
#   'year',
#   'ago',
#   'resurrect',
#   'crimin',
#   'sure',
#   'kinder',
#   'gentler',
#   'lobotomi',
#   'come',
#   'toyou',
#   'know',
#   'anesthesia',
#   'drill',
#   'hole',
#   'skull',
#   'veri',
#   'precis',
#   'instrument',
#   'destroy',
#   'veri',
#   'select',
#   'part',
#   'brain',
#   'let',
#   'hope',
#   'someon',
#   'come',
#   'prevent',
#   'horrif',
#   'ill',
#   'meanwhil',
#   'tri',
#   'normal',
#   'electro',
#   'shock',
#   'treatmentabsolut',
#   'barbar'],
#  ['thing',
#   'note',
#   'tim',
#   'keller',
#   'book',
#   'understand',
#   'biggest',
#   'name',
#   'associ',
#   'book',
#   'author',
#   'wrote',
#   'one',
#   'chapter',
#   'collabor',
#   'introduct',
#   'conclus',
#   'primari',
#   'author',
#   'john',
#   'inazu',
#   'list',
#   'second',
#   'cover',
#   'keller',
#   'book',
#   'essenti',
#   'elabor',
#   'explor',
#   'book',
#   'wrote',
#   'call',
#   'confid',
#   'plural',
#   'rest',
#   'chapter',
#   '12',
#   'total',
#   'written',
#   'writer',
#   'familiar',
#   'name',
#   'sara',
#   'grove',
#   'lecra',
#   'one',
#   'oh',
#   'guy',
#   'moment',
#   'read',
#   'chapter',
#   'written',
#   'guy',
#   'invit',
#   'black',
#   'live',
#   'matter',
#   'speak',
#   'urbana',
#   'surpris',
#   'anyon',
#   'disagre',
#   'decis',
#   'rememb',
#   'happen',
#   'rememb',
#   'name',
#   'associ',
#   'listen',
#   'noth',
#   'wrong',
#   'compil',
#   'camp',
#   'minut',
#   'market',
#   'book',
#   'mislead',
#   'base',
#   'cover',
#   'amazon',
#   'page',
#   'idea',
#   'tim',
#   'keller',
#   'wrote',
#   'book',
#   'assist',
#   'someon',
#   'like',
#   'never',
#   'heard',
#   'name',
#   'john',
#   'inazu',
#   'thumbnail',
#   'led',
#   'purchas',
#   'book',
#   'list',
#   'tim',
#   'keller',
#   'name',
#   'author',
#   'matter',
#   'great',
#   'huge',
#   'fan',
#   'john',
#   'inazu',
#   'book',
#   'love',
#   'lecra',
#   'sara',
#   'grove',
#   'contributor',
#   'might',
#   'buy',
#   'thi',
#   'frankli',
#   'huge',
#   'tim',
#   'keller',
#   'fan',
#   'might',
#   'purchas',
#   'whole',
#   'book',
#   'one',
#   'chapter',
#   'im',
#   'gen',
#   'xer',
#   'use',
#   'buy',
#   'whole',
#   'album',
#   'one',
#   'good',
#   'song',
#   'use',
#   'need',
#   'know',
#   'tim',
#   'keller',
#   'booki',
#   'could',
#   'go',
#   'deeper',
#   'critiqu',
#   'chapter',
#   'prais',
#   'say',
#   'uneven',
#   'compil',
#   'chapter',
#   'excel',
#   'see',
#   'keller',
#   'tim',
#   'chapter',
#   'okay',
#   'chapter',
#   'banal',
#   'sophomor',
#   'chapter',
#   'laud',
#   'pope',
#   'franci',
#   'immigr',
#   'polici',
#   'muse',
#   'made',
#   'eye',
#   'roll',
#   'violent',
#   'almost',
#   'lost',
#   'conscious',
#   'agre',
#   'view',
#   'refuge',
#   'crisi',
#   'disagre',
#   'particular',
#   'author',
#   'made',
#   'almost',
#   'attempt',
#   'engag',
#   'complex',
#   'nation',
#   'border',
#   'citizenship',
#   'question',
#   'beyond',
#   'admiss',
#   'interview',
#   'border',
#   'guard',
#   'discov',
#   'great',
#   'surpris',
#   'normal',
#   'human',
#   'gener',
#   'suggest',
#   'particular',
#   'chapter',
#   'belong',
#   'editori',
#   'page',
#   'colleg',
#   'newspaperanoth',
#   'review',
#   'rightli',
#   'point',
#   'anoth',
#   'problem',
#   'book',
#   'name',
#   'lack',
#   'specif',
#   'walk',
#   'wound',
#   'wayfar',
#   'reclaim',
#   'word',
#   'checklist',
#   'week',
#   'think',
#   'know',
#   'mean',
#   'guess',
#   'think',
#   'know',
#   'mean',
#   'mean',
#   'thing',
#   'probabl',
#   'iron',
#   'problem',
#   'book',
#   'tri',
#   'solvethi',
#   'final',
#   'complaint',
#   'big',
#   'one',
#   'one',
#   'reason',
#   'love',
#   'tim',
#   'keller',
#   'preach',
#   'write',
#   'allow',
#   'gospel',
#   'critiqu',
#   'conserv',
#   'liber',
#   'posit',
#   'find',
#   'good',
#   'intent',
#   'flaw',
#   'assumpt',
#   'undergird',
#   'posit',
#   'chapter',
#   'book',
#   'except',
#   'fantast',
#   'rest',
#   'author',
#   'leav',
#   'impress',
#   'real',
#   'problem',
#   'world',
#   'peopl',
#   'like',
#   'white',
#   'middleag',
#   'middleclass',
#   'suburban',
#   'polit',
#   'religi',
#   'conserv',
#   'peopl',
#   'fine',
#   'fulli',
#   'realiz',
#   'depth',
#   'sin',
#   'shortcom',
#   'critiqu',
#   'away',
#   'question',
#   'critiqu',
#   'anyon',
#   'els',
#   'gospel',
#   'anyth',
#   'say',
#   'leftlean',
#   'white',
#   'peopl',
#   'gospel',
#   'noth',
#   'say',
#   'black',
#   'brown',
#   'peopl',
#   'women',
#   '1',
#   'peopl',
#   'abl',
#   'write',
#   'bestsel',
#   'book',
#   'album',
#   'pick',
#   'let',
#   'say',
#   'explicitli',
#   'describ',
#   'author',
#   'book',
#   'none',
#   'except',
#   'keller',
#   'man',
#   'name',
#   'warren',
#   'kinghorn',
#   'white',
#   'grandson',
#   'infam',
#   'segregationist',
#   'believ',
#   'jesu',
#   'anyth',
#   'critic',
#   'say',
#   'author',
#   'book',
#   'attempt',
#   'engag',
#   'side',
#   'gospel',
#   'tim',
#   'keller',
#   'rest',
#   'author',
#   'clear',
#   'villain',
#   'mind',
#   'white',
#   'middleclass',
#   'republican',
#   'male',
#   'evangel',
#   'like',
#   'wear',
#   'red',
#   'america',
#   'great',
#   'hat',
#   'guy',
#   'exist',
#   'absolut',
#   'person',
#   'worthi',
#   'gospelcent',
#   'critiqu',
#   'ye',
#   'person',
#   'allow',
#   'repent',
#   'sure',
#   'sinc',
#   'problem',
#   'structur',
#   'individu',
#   'person',
#   'individu',
#   'repent',
#   'essenti',
#   'meaningless',
#   'oneway',
#   'critiqu',
#   'fill',
#   'book',
#   'fatal',
#   'flaw',
#   'oneway',
#   'critiqu',
#   'produc',
#   'twodimension',
#   'book',
#   'book',
#   'iron',
#   'undermin',
#   'whole',
#   'idea',
#   'find',
#   'common',
#   'groundif',
#   'like',
#   'buy',
#   'book',
#   'keller',
#   'chapter',
#   'great',
#   'good',
#   'chapter',
#   'familiar',
#   'john',
#   'inazu',
#   'realli',
#   'reson',
#   'book',
#   'plural',
#   'probabl',
#   'like',
#   'lot',
#   'look',
#   'find',
#   'common',
#   'ground',
#   'across',
#   'religi',
#   'polit',
#   'social',
#   'gender',
#   'line',
#   'look',
#   'elsewher'],
#  ['admit',
#   'fond',
#   'curmudgeonli',
#   'hero',
#   'grace',
#   'burrow',
#   'tendenc',
#   'write',
#   'began',
#   'delv',
#   'duke',
#   'name',
#   'met',
#   'nathaniel',
#   'rothmer',
#   'duke',
#   'rothhaven',
#   'almost',
#   'lost',
#   'heart',
#   'previou',
#   'book',
#   'author',
#   'grumpi',
#   'hero',
#   'still',
#   'alway',
#   'exud',
#   'utmost',
#   'courtesi',
#   'behav',
#   'like',
#   'gentlemen',
#   'fair',
#   'sex',
#   'nathaniel',
#   'downright',
#   'mean',
#   'abrupt',
#   'rude',
#   'everyon',
#   'even',
#   'heroin',
#   'even',
#   'went',
#   'far',
#   'threat',
#   'got',
#   'stori',
#   'began',
#   'see',
#   'whi',
#   'nathaniel',
#   'secret',
#   'larg',
#   'one',
#   'one',
#   'requir',
#   'keep',
#   'absolut',
#   'everyon',
#   'away',
#   'home',
#   'therefor',
#   'cant',
#   'friendship',
#   'never',
#   'allow',
#   'friend',
#   'come',
#   'call',
#   'run',
#   'household',
#   'elderli',
#   'remain',
#   'servant',
#   'total',
#   'loyal',
#   'cant',
#   'wife',
#   'even',
#   'casual',
#   'date',
#   'appear',
#   'lot',
#   'life',
#   'foreverladi',
#   'althea',
#   'wentworth',
#   'sister',
#   'duke',
#   'though',
#   'childhood',
#   'one',
#   'extrem',
#   'poverti',
#   'neglect',
#   'abus',
#   'societi',
#   'somewhat',
#   'mif',
#   'brother',
#   'inherit',
#   'lofti',
#   'titl',
#   'power',
#   'man',
#   'cross',
#   'cruel',
#   'member',
#   'ton',
#   'show',
#   'displeasur',
#   'life',
#   'miser',
#   'althea',
#   'instead',
#   'mock',
#   'subject',
#   'littl',
#   'act',
#   'vicious',
#   'althea',
#   'decid',
#   'retreat',
#   'yorkshir',
#   'estat',
#   'forego',
#   'anoth',
#   'london',
#   'season',
#   'long',
#   'children',
#   'famili',
#   'yet',
#   'unabl',
#   'fit',
#   'either',
#   'desper',
#   'decid',
#   'call',
#   'dread',
#   'duke',
#   'ask',
#   'social',
#   'advic',
#   'turn',
#   'away',
#   'home',
#   'multipl',
#   'time',
#   'take',
#   'desper',
#   'step',
#   'guarante',
#   'bring',
#   'duke',
#   'door',
#   'unexpect',
#   'action',
#   'involv',
#   'piggi',
#   'less',
#   'work',
#   'furiou',
#   'rothhaven',
#   'arriv',
#   'full',
#   'blusteri',
#   'modenathaniel',
#   'amaz',
#   'find',
#   'tea',
#   'sandwich',
#   'neighbor',
#   'intend',
#   'intimid',
#   'flatli',
#   'refus',
#   'spend',
#   'time',
#   'though',
#   'touch',
#   'need',
#   'fit',
#   'certainli',
#   'recogn',
#   'loneli',
#   'emot',
#   'familiar',
#   'realiz',
#   'need',
#   'escap',
#   'intrigu',
#   'unconvent',
#   'woman',
#   'nathaniel',
#   'teach',
#   'give',
#   'cut',
#   'direct',
#   'wish',
#   'let',
#   'know',
#   'wont',
#   'meet',
#   'againf',
#   'plan',
#   'meet',
#   'meet',
#   'long',
#   'grow',
#   'stronger',
#   'nathaniel',
#   'tell',
#   'althea',
#   'reason',
#   'cant',
#   'pursu',
#   'relationship',
#   'realiz',
#   'carri',
#   'heavi',
#   'burden',
#   'accid',
#   'happen',
#   'member',
#   'household',
#   'unabl',
#   'physician',
#   'come',
#   'home',
#   'nathaniel',
#   'desper',
#   'enough',
#   'ask',
#   'althea',
#   'help',
#   'stay',
#   'home',
#   'nurs',
#   'invalid',
#   'nathaniel',
#   'final',
#   'give',
#   'passion',
#   'agre',
#   'moment',
#   'time',
#   'cant',
#   'anyth',
#   'permanentth',
#   'secret',
#   'nathaniel',
#   'hide',
#   'reveal',
#   'fairli',
#   'earli',
#   'stori',
#   'think',
#   'one',
#   'reader',
#   'discov',
#   'mani',
#   'detail',
#   'flesh',
#   'stori',
#   'progress',
#   'show',
#   'nathaniel',
#   'truli',
#   'imposs',
#   'situat',
#   'read',
#   'think',
#   'oh',
#   'boy',
#   'ever',
#   'go',
#   'resolv',
#   'heartbreak',
#   'see',
#   'two',
#   'lone',
#   'peopl',
#   'found',
#   'genuin',
#   'love',
#   'cant',
#   'find',
#   'futur',
#   'togethernathaniel',
#   'care',
#   'love',
#   'selfsacrif',
#   'man',
#   'beneath',
#   'beastli',
#   'persona',
#   'creat',
#   'ador',
#   'althea',
#   'capabl',
#   'combin',
#   'strength',
#   'vulner',
#   'nathaniel',
#   'need',
#   'resolut',
#   'nathaniel',
#   'situat',
#   'one',
#   'wont',
#   'easi',
#   'realiz',
#   'like',
#   'explor',
#   'next',
#   'book',
#   'rogu',
#   'rich',
#   'seri',
#   'one',
#   'realli',
#   'realli',
#   'eager',
#   'read',
#   'said',
#   'duke',
#   'name',
#   'easili',
#   'read',
#   'standalon',
#   'coupl',
#   'achiev',
#   'happi',
#   'ever',
#   'mysteri',
#   'part',
#   'book',
#   'especi',
#   'intrigu',
#   'detail',
#   'past',
#   'heartbreak',
#   'im',
#   'happi',
#   'much',
#   'knowledg',
#   'today',
#   'certain',
#   'physic',
#   'mental',
#   'ill',
#   'treat',
#   'afflict',
#   'im',
#   'sorri',
#   'say',
#   'bulli',
#   'seem',
#   'someth',
#   'never',
#   'go',
#   'away',
#   'highli',
#   'recommend',
#   'duke',
#   'name',
#   'reader',
#   'enjoy',
#   'warm',
#   'romanc',
#   'charact',
#   'thoroughli',
#   'flesh',
#   'plot',
#   'uniqu',
#   'situat',
#   'touch',
#   'emot',
#   'entertain',
#   'youi',
#   'receiv',
#   'complimentari',
#   'copi',
#   'book'],
#  ['sinc',
#   'read',
#   'lot',
#   'book',
#   'usual',
#   'read',
#   'review',
#   'buy',
#   'disappoint',
#   'review',
#   'spend',
#   'word',
#   'tell',
#   'book',
#   'rather',
#   'like',
#   'dislik',
#   'particular',
#   'book',
#   'book',
#   'good',
#   'exampl',
#   'read',
#   'three',
#   'book',
#   'seri',
#   'enjoy',
#   'much',
#   'love',
#   'cosi',
#   'mysteri',
#   'find',
#   'charact',
#   'develop',
#   'good',
#   'one',
#   'enjoy',
#   'especi',
#   'main',
#   'charact',
#   'life',
#   'issu',
#   'work',
#   'solv',
#   'mysteri',
#   'three',
#   'book',
#   'addi',
#   'main',
#   'charact',
#   'deal',
#   'death',
#   'fiance',
#   'death',
#   'father',
#   'tri',
#   'settl',
#   'new',
#   'town',
#   'aunt',
#   'die',
#   'leav',
#   'larg',
#   'victorian',
#   'home',
#   'book',
#   'collect',
#   'mani',
#   'priceless',
#   'book',
#   'process',
#   'open',
#   'bookstor',
#   'cours',
#   'discov',
#   'dead',
#   'bodi',
#   'meet',
#   'good',
#   'look',
#   'chief',
#   'polic',
#   'involv',
#   'investig',
#   'three',
#   'book',
#   'addi',
#   'marc',
#   'chief',
#   'polic',
#   'begin',
#   'interest',
#   'one',
#   'anoth',
#   'although',
#   'addi',
#   'still',
#   'struggl',
#   'fiance',
#   'death',
#   'second',
#   'book',
#   'anoth',
#   'charact',
#   'ad',
#   'becom',
#   'possibl',
#   'love',
#   'interest',
#   'simon',
#   'new',
#   'doctor',
#   'town',
#   'medic',
#   'examin',
#   'addi',
#   'sluth',
#   'becom',
#   'friendli',
#   'creat',
#   'problem',
#   'marc',
#   'end',
#   'third',
#   'book',
#   'everyth',
#   'seem',
#   'sort',
#   'addi',
#   'marc',
#   'go',
#   'take',
#   'slow',
#   'relationship',
#   'simon',
#   'remain',
#   'friend',
#   'book',
#   'four',
#   'begin',
#   'reader',
#   'find',
#   'investig',
#   'marc',
#   'town',
#   'three',
#   'month',
#   'new',
#   'girlfriend',
#   'someth',
#   'happen',
#   'marc',
#   'addi',
#   'explan',
#   'happen',
#   'simon',
#   'back',
#   'love',
#   'interest',
#   'explan',
#   'come',
#   'later',
#   'book',
#   'seem',
#   'work',
#   'charact',
#   'develop',
#   'three',
#   'book',
#   'smooth',
#   'seem',
#   'almost',
#   'anoth',
#   'writer',
#   'taken',
#   'suddenli',
#   'decid',
#   'everyth',
#   'chang',
#   'opinion',
#   'author',
#   'chang',
#   'addi',
#   'marc',
#   'felt',
#   'one',
#   'anoth',
#   'book',
#   'three',
#   'differ',
#   'end',
#   'open',
#   'book',
#   'see',
#   'nasti',
#   'made',
#   'marc',
#   'treatment',
#   'addi',
#   'fit',
#   'charact',
#   'alreadi',
#   'start',
#   'develop',
#   'ye',
#   'polic',
#   'offic',
#   'follow',
#   'legal',
#   'procedur',
#   'addi',
#   'thing',
#   'annoy',
#   'contribut',
#   'clue',
#   'need',
#   'solv',
#   'case',
#   'three',
#   'book',
#   'marc',
#   'like',
#   'go',
#   'ask',
#   'seem',
#   'come',
#   'understand',
#   'final',
#   'understood',
#   'third',
#   'book',
#   'addi',
#   'still',
#   'tri',
#   'past',
#   'grief',
#   'open',
#   'head',
#   'someon',
#   'new',
#   'go',
#   'give',
#   'time',
#   'somewher',
#   'book',
#   'four',
#   'reader',
#   'find',
#   'three',
#   'month',
#   'agre',
#   'slow',
#   'relationship',
#   'tri',
#   'give',
#   'engag',
#   'ring',
#   'relationship',
#   'play',
#   'reader',
#   'end',
#   'book',
#   'four',
#   'addi',
#   'simon',
#   'new',
#   'love',
#   'interest',
#   'marc',
#   'suddenli',
#   'charact',
#   'look',
#   'shallow',
#   'sure',
#   'point',
#   'read',
#   'anymor',
#   'seri',
#   'perhap',
#   'next',
#   'book',
#   'addi',
#   'decid',
#   'love',
#   'marc',
#   'perhap',
#   'simon',
#   'meet',
#   'someon',
#   'new',
#   'mayb',
#   'say',
#   'heck',
#   'everyon',
#   'go',
#   'usual',
#   'cosi',
#   'mysteri',
#   'read',
#   'romant',
#   'interest',
#   'relationship',
#   'develop',
#   'number',
#   'book',
#   'seri',
#   'see',
#   'begin',
#   'adjust',
#   'new',
#   'relationship',
#   'accommod',
#   'relationship',
#   'grow',
#   'see',
#   'seri',
#   'book',
#   'sure',
#   'realli',
#   'like',
#   'author',
#   'chang',
#   'addi',
#   'marc',
#   'relationship',
#   'quickli',
#   'sudden',
#   'believ',
#   'jar',
#   'plot',
#   'line',
#   'much',
#   'read',
#   'kept',
#   'tri',
#   'understand',
#   'sudden',
#   'chang',
#   'relationship',
#   'sudden',
#   'chang',
#   'thought',
#   'interrupt',
#   'main',
#   'stori',
#   'line',
#   'affect',
#   'look',
#   'charact',
#   'addi',
#   'marc',
#   'henc',
#   'three',
#   'rate',
#   'three',
#   'five',
#   'thi',
#   'opinion',
#   'bare',
#   'three'],
#  ['rambuncti',
#   'teen',
#   'earli',
#   '80',
#   'becam',
#   'huge',
#   'van',
#   'halen',
#   'fan',
#   'spend',
#   'hour',
#   'listen',
#   'adrenalinepumpin',
#   'tune',
#   'stare',
#   'cassett',
#   'liner',
#   'note',
#   'kept',
#   'see',
#   'two',
#   'name',
#   'ted',
#   'templeman',
#   'donn',
#   'lande',
#   'idea',
#   'everi',
#   'vh',
#   'record',
#   'came',
#   'involv',
#   'success',
#   'band',
#   'book',
#   'final',
#   'shed',
#   'light',
#   'two',
#   'fella',
#   'true',
#   'import',
#   'van',
#   'halen',
#   'meteor',
#   'rise',
#   'top',
#   'rock',
#   'pantheonth',
#   'book',
#   'reveal',
#   'ted',
#   'humbl',
#   'guy',
#   'grew',
#   'near',
#   'san',
#   'francisco',
#   'whole',
#   'famili',
#   'involv',
#   'music',
#   'industri',
#   'capac',
#   'spent',
#   'childhood',
#   'work',
#   'piano',
#   'store',
#   'parent',
#   'tri',
#   'hand',
#   'perform',
#   'coupl',
#   'hit',
#   'harper',
#   'bizarr',
#   'late',
#   '60',
#   'ted',
#   'eventu',
#   'realiz',
#   'true',
#   'passion',
#   'produc',
#   'music',
#   'perform',
#   'road',
#   'big',
#   'break',
#   'came',
#   'ask',
#   'produc',
#   'doobi',
#   'brother',
#   'album',
#   '1971',
#   'continu',
#   'expertis',
#   'produc',
#   'paid',
#   'big',
#   'dividend',
#   'told',
#   'unsign',
#   'rock',
#   'band',
#   'la',
#   'call',
#   'van',
#   'halen',
#   'ted',
#   'blown',
#   'away',
#   'see',
#   'play',
#   'empti',
#   'room',
#   'starwood',
#   'sign',
#   'warner',
#   'bro',
#   'right',
#   'spota',
#   'lifelong',
#   'rothera',
#   'van',
#   'halen',
#   'fan',
#   'realli',
#   'love',
#   'book',
#   'ted',
#   'lavish',
#   'ton',
#   'prais',
#   'david',
#   'lee',
#   'roth',
#   'lyric',
#   'geniu',
#   'uniqu',
#   'gift',
#   'frontman',
#   'mighti',
#   'van',
#   'halen',
#   'kind',
#   'prais',
#   'lavish',
#   'noel',
#   'monk',
#   'book',
#   'came',
#   'year',
#   'ago',
#   'decad',
#   'sick',
#   'hear',
#   'vh',
#   'fan',
#   'say',
#   'dave',
#   'great',
#   'sammi',
#   'better',
#   'singer',
#   'two',
#   'insid',
#   'intim',
#   'knew',
#   'band',
#   'glori',
#   'year',
#   'say',
#   'exact',
#   'thing',
#   'david',
#   'lee',
#   'roth',
#   'gift',
#   'vocalist',
#   'terrif',
#   'frontman',
#   'absolut',
#   'essenti',
#   'rapid',
#   'rise',
#   'van',
#   'halen',
#   'peak',
#   'rock',
#   'stardom',
#   'last',
#   'legaci',
#   'fact',
#   'ted',
#   'admit',
#   'replac',
#   'dlr',
#   'sammi',
#   'hagar',
#   '1977',
#   'biggest',
#   'mistak',
#   'profession',
#   'life',
#   'david',
#   'lee',
#   'roth',
#   'repons',
#   'van',
#   'halen',
#   'biggest',
#   'rock',
#   'band',
#   'planet',
#   'deserv',
#   'much',
#   'prais',
#   'eddi',
#   'van',
#   'halen',
#   'spin',
#   'fact',
#   'pleas',
#   'shut',
#   'sammi',
#   'better',
#   'nonsens',
#   'nobodi',
#   'buy',
#   'malarkeyjust',
#   'like',
#   'noel',
#   'monk',
#   'halen',
#   'album',
#   '1984',
#   'bitter',
#   'end',
#   'ted',
#   'seem',
#   'harbor',
#   'resent',
#   'toward',
#   'vh',
#   'guy',
#   'day',
#   'end',
#   'neg',
#   'tone',
#   'templeman',
#   'seem',
#   'take',
#   'offens',
#   'thing',
#   'eddi',
#   'said',
#   'year',
#   'ted',
#   'royalti',
#   'vh',
#   'album',
#   'whole',
#   'van',
#   'hagar',
#   'situat',
#   'unfold',
#   'ted',
#   'ask',
#   'produc',
#   'van',
#   'hagar',
#   'album',
#   '5150',
#   'turn',
#   'didnt',
#   'tarnish',
#   'orgin',
#   'lineup',
#   'sign',
#   'made',
#   'superstar',
#   'ted',
#   'produc',
#   'dave',
#   'two',
#   'solo',
#   'album',
#   'eddi',
#   'becam',
#   'convinc',
#   'ted',
#   'pick',
#   'dave',
#   'side',
#   'split',
#   'caus',
#   'harsh',
#   'feel',
#   'two',
#   'ted',
#   'day',
#   'still',
#   'admir',
#   'respect',
#   'uniqu',
#   'talent',
#   'evhth',
#   'book',
#   'kind',
#   'sad',
#   'end',
#   'ted',
#   'talk',
#   'termin',
#   'warner',
#   'bro',
#   '1998',
#   'becam',
#   'depress',
#   'sank',
#   'lone',
#   'exist',
#   'alcohol',
#   'drug',
#   'abus',
#   'year',
#   'happen',
#   'one',
#   'odd',
#   'aspect',
#   'book',
#   'ted',
#   'bare',
#   'mention',
#   'wife',
#   'kid',
#   'even',
#   'though',
#   'long',
#   'happi',
#   'marriag',
#   'children',
#   'love',
#   'quickli',
#   'state',
#   'move',
#   'famili',
#   'pasadena',
#   'montecito',
#   'son',
#   'could',
#   'improv',
#   'asthma',
#   'condit',
#   'cleaner',
#   'air',
#   'littl',
#   'know',
#   'life',
#   'event',
#   'ted',
#   'subltli',
#   'mention',
#   'sever',
#   'hous',
#   '80',
#   'drove',
#   'ferrari',
#   'roll',
#   'royc',
#   'lucr',
#   'real',
#   'estat',
#   'invest',
#   'appear',
#   'platinum',
#   'produc',
#   'paid',
#   'handsom',
#   'day',
#   'hope',
#   'ted',
#   'templeman',
#   'induct',
#   'rock',
#   'n',
#   'roll',
#   'hall',
#   'fame',
#   'die',
#   'deserv',
#   'recognit',
#   'produc',
#   'biggest',
#   'rock',
#   'album',
#   '70',
#   '80'],
#  ['rambuncti',
#   'teen',
#   'earli',
#   '80',
#   'becam',
#   'huge',
#   'van',
#   'halen',
#   'fan',
#   'spend',
#   'hour',
#   'listen',
#   'adrenalinepumpin',
#   'tune',
#   'stare',
#   'cassett',
#   'liner',
#   'note',
#   'kept',
#   'see',
#   'two',
#   'name',
#   'ted',
#   'templeman',
#   'donn',
#   'lande',
#   'idea',
#   'everi',
#   'vh',
#   'record',
#   'came',
#   'involv',
#   'success',
#   'band',
#   'book',
#   'final',
#   'shed',
#   'light',
#   'two',
#   'fella',
#   'true',
#   'import',
#   'van',
#   'halen',
#   'meteor',
#   'rise',
#   'top',
#   'rock',
#   'pantheonth',
#   'book',
#   'reveal',
#   'ted',
#   'humbl',
#   'guy',
#   'grew',
#   'near',
#   'san',
#   'francisco',
#   'whole',
#   'famili',
#   'involv',
#   'music',
#   'industri',
#   'capac',
#   'spent',
#   'childhood',
#   'work',
#   'piano',
#   'store',
#   'parent',
#   'tri',
#   'hand',
#   'perform',
#   'coupl',
#   'hit',
#   'harper',
#   'bizarr',
#   'late',
#   '60',
#   'ted',
#   'eventu',
#   'realiz',
#   'true',
#   'passion',
#   'produc',
#   'music',
#   'perform',
#   'road',
#   'big',
#   'break',
#   'came',
#   'ask',
#   'produc',
#   'doobi',
#   'brother',
#   'album',
#   '1971',
#   'continu',
#   'expertis',
#   'produc',
#   'paid',
#   'big',
#   'dividend',
#   'told',
#   'unsign',
#   'rock',
#   'band',
#   'la',
#   'call',
#   'van',
#   'halen',
#   'ted',
#   'blown',
#   'away',
#   'see',
#   'play',
#   'empti',
#   'room',
#   'starwood',
#   'sign',
#   'warner',
#   'bro',
#   'right',
#   'spota',
#   'lifelong',
#   'rothera',
#   'van',
#   'halen',
#   'fan',
#   'realli',
#   'love',
#   'book',
#   'ted',
#   'lavish',
#   'ton',
#   'prais',
#   'david',
#   'lee',
#   'roth',
#   'lyric',
#   'geniu',
#   'uniqu',
#   'gift',
#   'frontman',
#   'mighti',
#   'van',
#   'halen',
#   'kind',
#   'prais',
#   'lavish',
#   'noel',
#   'monk',
#   'book',
#   'came',
#   'year',
#   'ago',
#   'decad',
#   'sick',
#   'hear',
#   'vh',
#   'fan',
#   'say',
#   'dave',
#   'great',
#   'sammi',
#   'better',
#   'singer',
#   'two',
#   'insid',
#   'intim',
#   'knew',
#   'band',
#   'glori',
#   'year',
#   'say',
#   'exact',
#   'thing',
#   'david',
#   'lee',
#   'roth',
#   'gift',
#   'vocalist',
#   'terrif',
#   'frontman',
#   'absolut',
#   'essenti',
#   'rapid',
#   'rise',
#   'van',
#   'halen',
#   'peak',
#   'rock',
#   'stardom',
#   'last',
#   'legaci',
#   'fact',
#   'ted',
#   'admit',
#   'replac',
#   'dlr',
#   'sammi',
#   'hagar',
#   '1977',
#   'biggest',
#   'mistak',
#   'profession',
#   'life',
#   'david',
#   'lee',
#   'roth',
#   'repons',
#   'van',
#   'halen',
#   'biggest',
#   'rock',
#   'band',
#   'planet',
#   'deserv',
#   'much',
#   'prais',
#   'eddi',
#   'van',
#   'halen',
#   'spin',
#   'fact',
# ...
#   'realiz',
#   'interplay',
#   'intimaci',
#   'individu',
#   'person',
#   'destini',
#   'event',
#   'uniqu',
#   'common',
#   'forg',
#   'charact',
#   'send',
#   'dispar',
#   'outpost',
#   'frontier',
#   'weav',
#   'full',
#   'life',
#   'commit',
#   'courag',
#   'typic',
#   'western',
#   'novel',
#   'perfidi',
#   'bravado',
#   'art',
#   'depict',
#   'real',
#   'peopl',
#   'live',
#   'real',
#   'live',
#   'real',
#   'place',
#   'true',
#   'hors',
#   'girl',
#   'die'],
#  ['big',
#   'fan',
#   'jone',
#   'charley',
#   'davidson',
#   'seri',
#   'super',
#   'excit',
#   'see',
#   'thi',
#   'love',
#   'oe',
#   'book',
#   'got',
#   '100',
#   'page',
#   'end',
#   'start',
#   'sad',
#   'end',
#   'plu',
#   'know',
#   'standalon',
#   'part',
#   'seri',
#   'sure',
#   'everyth',
#   'wrap',
#   'cleanli',
#   'leav',
#   'hang',
#   'book',
#   'one',
#   'left',
#   'hang',
#   'right',
#   'amount',
#   'start',
#   'count',
#   'mani',
#   'day',
#   'nether',
#   'onesunshin',
#   'vicram',
#   'mysteri',
#   'elect',
#   'sheriff',
#   'hometown',
#   'sure',
#   'happen',
#   'sinc',
#   'offici',
#   'enter',
#   'race',
#   'humor',
#   'charact',
#   'interact',
#   'engag',
#   'mysteri',
#   'storylin',
#   'come',
#   'expect',
#   'jone',
#   'kept',
#   'smile',
#   'cant',
#   'wait',
#   'next',
#   'one'],
#  ['honestli',
#   'say',
#   'read',
#   'introduct',
#   'readi',
#   'recommend',
#   'book',
#   'everyon',
#   'know',
#   'id',
#   'like',
#   'box',
#   'hand',
#   'stranger',
#   'meet',
#   'distanc',
#   'stori',
#   'book',
#   'pay',
#   'forward',
#   'ive',
#   'alreadi',
#   'purchas',
#   'copi',
#   'act',
#   'kind',
#   'toward',
#   'someon',
#   'kind',
#   'meon',
#   'thing',
#   'keep',
#   'us',
#   'go',
#   'right',
#   'stori',
#   'incred',
#   'act',
#   'love',
#   'kind',
#   'display',
#   'peopl',
#   'across',
#   'countri',
#   'across',
#   'world',
#   'amidst',
#   'pandem',
#   'public',
#   'salut',
#   'health',
#   'care',
#   'worker',
#   'commit',
#   'compani',
#   'retain',
#   'employe',
#   'simpl',
#   'stay',
#   'safe',
#   'express',
#   'remind',
#   'much',
#   'love',
#   'kind',
#   'matter',
#   'book',
#   'full',
#   'exampl',
#   'act',
#   'especi',
#   'need',
#   'word',
#   'messag',
#   'book',
#   'one',
#   'carri',
#   'us',
#   'everi',
#   'day'],
#  ['never',
#   'written',
#   'amazon',
#   'review',
#   'share',
#   'much',
#   'love',
#   'new',
#   'cookbook',
#   'alreadi',
#   'made',
#   '8',
#   'recip',
#   'cookbook',
#   'week',
#   'amaz',
#   'best',
#   'part',
#   'pamela',
#   'give',
#   'mani',
#   'variat',
#   'tip',
#   'work',
#   'individu',
#   'food',
#   'sensit',
#   'clear',
#   'instruct',
#   'learn',
#   'lot',
#   'explan',
#   'plu',
#   'recip',
#   'super',
#   'quick',
#   'easi',
#   'mani',
#   'cookbook',
#   'sit',
#   'shelv',
#   'mayb',
#   'cook',
#   'one',
#   'two',
#   'recip',
#   'liter',
#   'stop',
#   'bookmark',
#   'page',
#   'recip',
#   'quicker',
#   'quick',
#   'ridicul',
#   'mani',
#   'tag',
#   'keep',
#   'cant',
#   'go',
#   'wrong',
#   'either',
#   'cookbook',
#   'highli',
#   'recommend',
#   'daili',
#   'instagram',
#   'live',
#   'incred',
#   'help',
#   'check'],
#  ['beachsid',
#   'beginningsa',
#   'moonlight',
#   'harbor',
#   'novelthi',
#   '4th',
#   'book',
#   'moonlight',
#   'harbor',
#   'seri',
#   'delight',
#   'readi',
#   'read',
#   'book',
#   'less',
#   '24',
#   'hour',
#   'couldnt',
#   'put',
#   'captiv',
#   'page',
#   'last',
#   'pageth',
#   'charact',
#   'mani',
#   'familiar',
#   'name',
#   'three',
#   'book',
#   'edi',
#   'patterson',
#   'jenna',
#   'jone',
#   'brodi',
#   'green',
#   'seth',
#   'water',
#   'courtney',
#   'moor',
#   'pete',
#   'long',
#   'new',
#   'charact',
#   'like',
#   'moira',
#   'wellmanther',
#   'mani',
#   'emot',
#   'book',
#   'good',
#   'sad',
#   'help',
#   'book',
#   'fantast',
#   'read',
#   'hope',
#   'seri',
#   'jenna',
#   'final',
#   'admit',
#   'better',
#   'man',
#   'sethi',
#   'guarante',
#   'wont',
#   'go',
#   'wrong',
#   'read',
#   'book',
#   'entir',
#   'seri',
#   'moonlight',
#   'harbor',
#   'lot',
#   'offer',
#   'everyonesheila',
#   'robert',
#   'keep',
#   'write',
#   'wonder',
#   'stori',
#   'us',
#   'enjoy',
#   'person',
#   'hope',
#   'continu'],
#  ['fear',
#   'immort',
#   'soul',
#   'real',
#   'problem',
#   'land',
#   'becar',
#   'realm',
#   'die',
#   'reincarn',
#   'base',
#   'good',
#   'soul',
#   'like',
#   'come',
#   'back',
#   'anim',
#   'rare',
#   'pure',
#   'enough',
#   'come',
#   'back',
#   'human',
#   'worst',
#   'worst',
#   'come',
#   'back',
#   'kehok',
#   'monstrou',
#   'creatur',
#   'random',
#   'amalgam',
#   'differ',
#   'creatur',
#   'kehok',
#   'live',
#   'kill',
#   'destroy',
#   'alway',
#   'reincarn',
#   'noth',
#   'kehok',
#   'stop',
#   'brave',
#   'foolhardi',
#   'captur',
#   'train',
#   'kehok',
#   'run',
#   'annual',
#   'race',
#   'prize',
#   'money',
#   'enorm',
#   'kehok',
#   'win',
#   'grand',
#   'championship',
#   'grant',
#   'charm',
#   'allow',
#   'reincarn',
#   'human',
#   'upon',
#   'deaththi',
#   'year',
#   'trainer',
#   'tamra',
#   'desper',
#   'need',
#   'sponsor',
#   'rider',
#   'win',
#   'kehok',
#   'race',
#   'daughter',
#   'train',
#   'auger',
#   'gift',
#   'individu',
#   'read',
#   'person',
#   'aura',
#   'determin',
#   'kind',
#   'creatur',
#   'reincarn',
#   'auger',
#   'school',
#   'expens',
#   'tamra',
#   'cant',
#   'pay',
#   'fee',
#   'auger',
#   'assum',
#   'full',
#   'custodi',
#   'daughter',
#   'good',
#   'countri',
#   'tamra',
#   'never',
#   'see',
#   'daughter',
#   'find',
#   'raia',
#   'runaway',
#   'teen',
#   'fire',
#   'person',
#   'noth',
#   'lose',
#   'goe',
#   'better',
#   'judgement',
#   'agre',
#   'train',
#   'two',
#   'women',
#   'alreadi',
#   'enough',
#   'pressur',
#   'soon',
#   'discov',
#   'kehok',
#   'particularli',
#   'unusu',
#   'exist',
#   'soon',
#   'embroil',
#   'power',
#   'struggl',
#   'fate',
#   'countryrac',
#   'sand',
#   'engag',
#   'fantasi',
#   'tale',
#   'rais',
#   'kind',
#   'question',
#   'moral',
#   'drive',
#   'person',
#   'good',
#   'becar',
#   'entir',
#   'system',
#   'power',
#   'base',
#   'upon',
#   'system',
#   'reincarn',
#   'fear',
#   'soul',
#   'come',
#   'back',
#   'wealthi',
#   'maintain',
#   'control',
#   'custom',
#   'believ',
#   'wealth',
#   'reward',
#   'god',
#   'puriti',
#   'soul',
#   'fact',
#   'aura',
#   'read',
#   'privat',
#   'keep',
#   'anyth',
#   'assail',
#   'myth',
#   'auger',
#   'live',
#   'unblemish',
#   'live',
#   'given',
#   'noth',
#   'respect',
#   'abil',
#   'see',
#   'futur',
#   'give',
#   'right',
#   'destroy',
#   'famili',
#   'quest',
#   'new',
#   'member',
#   'tamra',
#   'rais',
#   'excel',
#   'point',
#   'rememb',
#   'past',
#   'life',
#   'next',
#   'bodi',
#   'anyth',
#   'except',
#   'best',
#   'right',
#   'moment',
#   'good',
#   'right',
#   'thing',
#   'simpli',
#   'might',
#   'come',
#   'back',
#   'toad',
#   'next',
#   'life',
#   'kind',
#   'question',
#   'kick',
#   'around',
#   'stori',
#   'begin',
#   'simpl',
#   'premis',
#   'monsterracingtamra',
#   'raia',
#   'two',
#   'excel',
#   'femal',
#   'lead',
#   'anchor',
#   'adventur',
#   'tamra',
#   'core',
#   'iron',
#   'power',
#   'allow',
#   'control',
#   'kehok',
#   'main',
#   'moral',
#   'compass',
#   'book',
#   'blunt',
#   'enough',
#   'ask',
#   'question',
#   'without',
#   'concern',
#   'rank',
#   'etiquett',
#   'push',
#   'auger',
#   'fall',
#   'compani',
#   'reexamin',
#   'belief',
#   'raia',
#   'hand',
#   'spark',
#   'born',
#   'desper',
#   'escap',
#   'control',
#   'famili',
#   'overcom',
#   'self',
#   'doubt',
#   'believ',
#   'lifetim',
#   'failur',
#   'along',
#   'tamra',
#   'daughter',
#   'shalla',
#   'famili',
#   'unit',
#   'built',
#   'weather',
#   'kind',
#   'stormsth',
#   'central',
#   'thrust',
#   'race',
#   'sand',
#   'familiar',
#   'less',
#   'enjoy',
#   'rooki',
#   'rider',
#   'curmudgeonli',
#   'veteran',
#   'trainer',
#   'hors',
#   'monster',
#   'everyon',
#   'believ',
#   'untrain',
#   'fight',
#   'underdog',
#   'win',
#   'grand',
#   'championship',
#   'race',
#   'extra',
#   'layer',
#   'race',
#   'sand',
#   'surpris',
#   'welcom',
#   'addit',
#   'promis',
#   'book',
#   'jacket',
#   'ye',
#   'larg',
#   'book',
#   'monsterrac',
#   'level',
#   'polit',
#   'intrigu',
#   'tension',
#   'capitol',
#   'citi',
#   'revolv',
#   'around',
#   'soontobecrown',
#   'emperor',
#   'tension',
#   'attempt',
#   'manipul',
#   'involv',
#   'soon',
#   'spill',
#   'race',
#   'themselv',
#   'capitol',
#   'final',
#   'championship',
#   'race',
#   'held',
#   'stake',
#   'elev',
#   'beyond',
#   'tamra',
#   'raia',
#   'person',
#   'problem',
#   'becom',
#   'fate',
#   'countri',
#   'wholeon',
#   'thing',
#   'use',
#   'book',
#   'magic',
#   'system',
#   'visual',
#   'flashi',
#   'auger',
#   'cant',
#   'see',
#   'aura',
#   'pov',
#   'charact',
#   'actual',
#   'auger',
#   'go',
#   'faith',
#   'proclam',
#   'reincarn',
#   'true',
#   'fair',
#   'one',
#   'point',
#   'book',
#   'almost',
#   'wish',
#   'given',
#   'pov',
#   'nonaug',
#   'keep',
#   'us',
#   'state',
#   'uncertainti',
#   'populac',
#   'whole',
#   'regardless',
#   'stop',
#   'book',
#   'rais',
#   'question',
#   'system',
#   'question',
#   'appli',
#   'real',
#   'world',
#   'religion',
#   'gain',
#   'wield',
#   'powerrac',
#   'sand',
#   'rous',
#   'standalon',
#   'fantasi',
#   'adventur',
#   'kind',
#   'start',
#   'small',
#   'person',
#   'scale',
#   'eventu',
#   'grow',
#   'final',
#   'shake',
#   'becar',
#   'core',
#   'scratch',
#   'itch',
#   'human',
#   'bond',
#   'magic',
#   'creatur',
#   'trope',
#   'even',
#   'particular',
#   'magic',
#   'creatur',
#   'reincarn',
#   'human',
#   'mood',
#   'monster',
#   'race',
#   'primarili',
#   'femal',
#   'cast',
#   'surviv',
#   'odd',
#   'race',
#   'sand',
#   'deliv',
#   'count',
#   'one',
#   'delight',
#   'packag',
#   'requir',
#   'seri',
#   'commitmentnot',
#   'provid',
#   'arc',
#   'book',
#   'publish',
#   'return',
#   'fair',
#   'honest',
#   'review'],
#  ['love',
#   'titl',
#   'book',
#   'someth',
#   'sure',
#   'like',
#   'coupl',
#   'chapter',
#   'made',
#   'put',
#   'persev',
#   'sever',
#   'day',
#   'finish',
#   'cours',
#   'stori',
#   'shut',
#   'social',
#   'media',
#   'account',
#   'could',
#   'iti',
#   'actual',
#   'reason',
#   'ill',
#   'andi',
#   'sever',
#   'seriou',
#   'health',
#   'problem',
#   'lose',
#   'anoth',
#   'job',
#   'dt',
#   'tell',
#   'addict',
#   'devic',
#   'decid',
#   'tri',
#   'wean',
#   'friend',
#   'write',
#   'paper',
#   'convinc',
#   'hi',
#   'let',
#   'write',
#   'cours',
#   'becom',
#   'famou',
#   'peopl',
#   'recogn',
#   'hate',
#   'mani',
#   'escapad',
#   'latersom',
#   'funni',
#   'mani',
#   'crazi',
#   'happen',
#   'delight',
#   'end',
#   'past',
#   'coupl',
#   'chapter',
#   'turn',
#   'good',
#   'somewhat',
#   'crazi',
#   'book'],
#  ['lesli',
#   'deepli',
#   'passion',
#   'help',
#   'write',
#   'life',
#   'stori',
#   'write',
#   'person',
#   'narr',
#   'firmli',
#   'believ',
#   'help',
#   'us',
#   'move',
#   'forward',
#   'live',
#   'fulli',
#   'approach',
#   'write',
#   'memoir',
#   'involv',
#   'deconstruct',
#   'chronolog',
#   'method',
#   'move',
#   'accept',
#   'challeng',
#   'write',
#   'creativ',
#   'keep',
#   'word',
#   'journal',
#   'expand',
#   'vocabulari',
#   'thu',
#   'interest',
#   'writer',
#   'use',
#   'less',
#   'word',
#   'pack',
#   'punch',
#   'belabor',
#   'ghost',
#   'past',
#   'believ',
#   'must',
#   'write',
#   'honestli',
#   'transpar',
#   'subject',
#   'reader',
#   'uninterest',
#   'narr',
#   'push',
#   'writer',
#   'nurtur',
#   'develop',
#   'scene',
#   'draw',
#   'reader',
#   'help',
#   'identifi',
#   'stori',
#   'seriou',
#   'writer',
#   'obvious',
#   'challeng',
#   'writer',
#   'use',
#   'written',
#   'narr',
#   'prayer',
#   'expos',
#   'truth',
#   'set',
#   'free',
#   'process'],
#  ['modern',
#   'english',
#   'translat',
#   'latin',
#   'poetic',
#   'treatis',
#   'drink',
#   'alcohol',
#   'origin',
#   'publish',
#   'germani',
#   '1536',
#   'readabl',
#   'relev',
#   'provid',
#   'advic',
#   'drink',
#   'kind',
#   'peopl',
#   'drink',
#   'keep',
#   'thing',
#   'moder',
#   'kind',
#   'song',
#   'sing',
#   'etc',
#   'origin',
#   'latin',
#   'text',
#   'prose',
#   'translat',
#   'provid',
#   'latin',
#   'literatur',
#   'period',
#   'hardli',
#   'attent',
#   'refresh',
#   'see',
#   'book',
#   'like',
#   'thi',
#   'tone',
#   'work',
#   'humor',
#   'lace',
#   'plenti',
#   'ground',
#   'life',
#   'advic',
#   'cautionari',
#   'warn',
#   'fascin',
#   'work',
#   'shed',
#   'lot',
#   'light',
#   'reformationera',
#   'life',
#   'northern',
#   'europ',
#   'say',
#   'book',
#   'hardcov',
#   'edit',
#   'beauti',
#   'design',
#   'small',
#   'almost',
#   'pockets',
#   'nice',
#   'illustr',
#   'ancient',
#   'drinkingvessel'],
#  ['ok',
#   'book',
#   'long',
#   'term',
#   'warrior',
#   'fan',
#   'new',
#   'seri',
#   'appeal',
#   'much',
#   'mush',
#   'go',
#   '3',
#   'charact',
#   'three',
#   'thing',
#   'one',
#   'shawdowclan',
#   'riverclan',
#   'think',
#   'write',
#   'review',
#   '3',
#   'month',
#   'later',
#   'lol',
#   'thunderclan',
#   'cours',
#   'everyth',
#   'spread',
#   'like',
#   'three',
#   'jay',
#   'feather',
#   'lionblaz',
#   'hollyleaf',
#   'clan',
#   'less',
#   'spread',
#   'sens',
#   'need',
#   'bit',
#   'moresuspens',
#   'plot',
#   'twist',
#   'much',
#   'predic',
#   'book',
#   'thunderclan',
#   'import',
#   'use',
#   'sinc',
#   'seri',
#   'import',
#   'clan',
#   'alway',
#   'hero',
#   'thought',
#   'might',
#   'focu',
#   'windclan',
#   'mayb',
#   'bit',
#   'riverclan',
#   'mayb',
#   'even',
#   'shadow',
#   'clan',
#   'thought',
#   'mayb',
#   'erin',
#   'team',
#   'chang',
#   'shadowclan',
#   'reput',
#   'evil',
#   'least',
#   'reput',
#   'tigerstar',
#   'brokenstar'],
#  ['delacort',
#   'press',
#   'netgalley',
#   'provid',
#   'electron',
#   'copi',
#   'lucki',
#   'one',
#   'voluntarili',
#   'chose',
#   'review',
#   'novel',
#   'opinion',
#   'freeli',
#   'givenmay',
#   'surviv',
#   'school',
#   'shoot',
#   'feel',
#   'lucki',
#   'lose',
#   'twin',
#   'brother',
#   'friend',
#   'favorit',
#   'teacher',
#   'made',
#   'may',
#   'feel',
#   'tremend',
#   'guilt',
#   'anger',
#   'though',
#   'year',
#   'may',
#   'find',
#   'leav',
#   'feel',
#   'behind',
#   'move',
#   'forwardzach',
#   'feel',
#   'tremend',
#   'guilt',
#   'mother',
#   'lawyer',
#   'charg',
#   'defend',
#   'school',
#   'shooter',
#   'mother',
#   'made',
#   'life',
#   'exceedingli',
#   'difficult',
#   'zach',
#   'sister',
#   'zach',
#   'meet',
#   'may',
#   'pair',
#   'abl',
#   'put',
#   'asid',
#   'differ',
#   'focu',
#   'futureliz',
#   'lawson',
#   'say',
#   'best',
#   'author',
#   'note',
#   'lucki',
#   'one',
#   'haunt',
#   'face',
#   'yet',
#   'face',
#   'human',
#   'collater',
#   'damag',
#   'shoot',
#   'live',
#   'rip',
#   'split',
#   'open',
#   'use',
#   'media',
#   'fodder',
#   'forgotten',
#   'world',
#   'move',
#   'like',
#   'fact',
#   'author',
#   'chose',
#   'focu',
#   'aftermath',
#   'shoot',
#   'instead',
#   'actual',
#   'event',
#   'reader',
#   'learn',
#   'enough',
#   'stori',
#   'need',
#   'graphic',
#   'detail',
#   'may',
#   'suffer',
#   'pain',
#   'seem',
#   'real',
#   'especi',
#   'descript',
#   'panic',
#   'attack',
#   'hole',
#   'stori',
#   'howev',
#   'hold',
#   'lucki',
#   'one',
#   'back',
#   'great',
#   'without',
#   'specif',
#   'shooter',
#   'given',
#   'leeway',
#   'realist',
#   'may',
#   'situat',
#   'seem',
#   'imposs',
#   'found',
#   'overal',
#   'lucki',
#   'one',
#   'time',
#   'involv',
#   'situat',
#   'common',
#   'today',
#   'societi',
#   'parent',
#   'read',
#   'book',
#   'teen',
#   'provid',
#   'jump',
#   'point',
#   'real',
#   'convers'],
#  ['loneli',
#   'wors',
#   'sadnessloneli',
#   'definit',
#   'cannot',
#   'sharedthi',
#   'move',
#   'stori',
#   'told',
#   'mainli',
#   'mother',
#   'daughter',
#   'pointofview',
#   'sufferedsuff',
#   'terribl',
#   'postpartum',
#   'depressiongrac',
#   'young',
#   'mother',
#   '195657',
#   'four',
#   'children',
#   'age',
#   'five',
#   'husband',
#   'believ',
#   'birth',
#   'control',
#   'distanc',
#   'famili',
#   'work',
#   'drinkingbeth',
#   'youngest',
#   'grace',
#   'daughter',
#   '1996',
#   'new',
#   'babi',
#   'plu',
#   'father',
#   'sibl',
#   'dearli',
#   'love',
#   'hospic',
#   'carethi',
#   'book',
#   'famili',
#   'stigma',
#   'andor',
#   'ignor',
#   'depress',
#   'imposs',
#   'choicesthi',
#   'emot',
#   'difficult',
#   'stori',
#   'read',
#   'tie',
#   'famili',
#   'overcom',
#   'adversityi',
#   'receiv',
#   'book',
#   'grayson',
#   'hous',
#   'net',
#   'galley',
#   'hope',
#   'read',
#   'leav',
#   'unbias',
#   'review'],
#  ['spirit',
#   'full',
#   'disclosur',
#   'admit',
#   'lesli',
#   'atkin',
#   'groupi',
#   'come',
#   'travel',
#   'book',
#   'love',
#   'read',
#   'fill',
#   'fascin',
#   'tidbit',
#   'histori',
#   'eloqu',
#   'descript',
#   'variou',
#   'locat',
#   'almost',
#   'smell',
#   'breez',
#   'water',
#   'feel',
#   'sunshin',
#   'latest',
#   'book',
#   'disappointthi',
#   'one',
#   'stretch',
#   'pennsylvania',
#   'brandywin',
#   'valley',
#   'delawar',
#   'maryland',
#   'coast',
#   'virginia',
#   'eastern',
#   'shore',
#   'use',
#   'book',
#   'guid',
#   'plan',
#   'trip',
#   'take',
#   'advantag',
#   'suggest',
#   'itinerari',
#   'either',
#   'privi',
#   'hidden',
#   'gem',
#   'sight',
#   'runof',
#   'themil',
#   'guid',
#   'book',
#   'know',
#   'delight',
#   'place',
#   'stay',
#   'local',
#   'food',
#   'tasteand',
#   'us',
#   'armchair',
#   'travel',
#   'part',
#   'take',
#   'great',
#   'joy',
#   'travel',
#   'vicari',
#   'wellresearch',
#   'engaginglywritten',
#   'book'],
#  ...]

# %%
import gensim
from gensim import corpora, models
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import gensim
#       2 from gensim import corpora, models
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/corpora/__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/corpora/indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)     14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~/Amazon_BookReviews/venv/lib/python3.11/site-packages/gensim/_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
